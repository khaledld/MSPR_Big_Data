# %%
import numpy as np
import pandas as pd
  
mdnv_data = pd.read_excel("E:/Ingénierie 1 EISI/MSPR 1/Projet MSPR Big Data/Datasets/Used Datasets/Code_Com_Code_Departement-_Taux_pauvrete-base-cc-filosofi-2022.xlsx", sheet_name='COM')
mdnv_data
# Out:
#       Fichier Localisé Social et Fiscal (FiLoSoFi) - Année 2021  \
# 0                 Communes et arrondissements municipaux
# 1      Mise en ligne le 29/01/2024       Géographie a...
# 2      @Insee       Source(s) : Insee-DGFIP-Cnaf-Cnav...
# 3                                      Code géographique
# 4                                                 CODGEO
# ...                                                  ...
# 34919                                              97420
# 34920                                              97421
# 34921                                              97422
# 34922                                              97423
# 34923                                              97424
#
#                  Unnamed: 1                 Unnamed: 2  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# ...

# %%
new_col = mdnv_data.iloc[3]
mdnv_data.columns = new_col
mdnv_data
# Out:
# 3                                      Code géographique  \
# 0                 Communes et arrondissements municipaux
# 1      Mise en ligne le 29/01/2024       Géographie a...
# 2      @Insee       Source(s) : Insee-DGFIP-Cnaf-Cnav...
# 3                                      Code géographique
# 4                                                 CODGEO
# ...                                                  ...
# 34919                                              97420
# 34920                                              97421
# 34921                                              97422
# 34922                                              97423
# 34923                                              97424
#
# 3      Libellé géographique  Nombre de ménages fiscaux  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# ...

# %%
mdnv_data = mdnv_data.drop(mdnv_data.index[:1])
mdnv_data.reset_index(drop=True)
mdnv_data
# Out:
# 3     Code géographique     Libellé géographique Nombre de ménages fiscaux  \
# 5                 01001  L'Abergement-Clémenciat                       346
# 6                 01002    L'Abergement-de-Varey                       115
# 7                 01004        Ambérieu-en-Bugey                      6855
# 8                 01005      Ambérieux-en-Dombes                       800
# 9                 01006                  Ambléon                        51
# ...                 ...                      ...                       ...
# 34919             97420           Sainte-Suzanne                      8593
# 34920             97421                  Salazie                      2472
# 34921             97422                Le Tampon                     31239
# 34922             97423        Les Trois-Bassins                      2505
# 34923             97424                   Cilaos                      2142
#
# ...

# %%
mdnv_data.columns.name = ""

# %%
mdnv_data = mdnv_data.reset_index(drop=True)

# %%
mdnv_data
# Out:
#       Code géographique     Libellé géographique Nombre de ménages fiscaux  \
# 0                 01001  L'Abergement-Clémenciat                       346
# 1                 01002    L'Abergement-de-Varey                       115
# 2                 01004        Ambérieu-en-Bugey                      6855
# 3                 01005      Ambérieux-en-Dombes                       800
# 4                 01006                  Ambléon                        51
# ...                 ...                      ...                       ...
# 34914             97420           Sainte-Suzanne                      8593
# 34915             97421                  Salazie                      2472
# 34916             97422                Le Tampon                     31239
# 34917             97423        Les Trois-Bassins                      2505
# 34918             97424                   Cilaos                      2142
#
# ...

# %%
data = mdnv_data

# %%
needed_cols = ['Code géographique', 'Médiane du niveau vie (€)']

mdnv_data = mdnv_data.drop(columns=[col for col in mdnv_data.columns if col not in needed_cols])
mdnv_data
# Out:
#       Code géographique Médiane du niveau vie (€)
# 0                 01001                     25820
# 1                 01002                     24480
# 2                 01004                     21660
# 3                 01005                     24610
# 4                 01006                     24210
# ...                 ...                       ...
# 34914             97420                     17720
# 34915             97421                     13280
# 34916             97422                     16560
# 34917             97423                     16680
# 34918             97424                     13780
#
# [34919 rows x 2 columns]

# %%
import os

rep_dir = "E:\Ingénierie 1 EISI\MSPR 1\Projet MSPR Big Data\Datasets\Extraxted Data"
if not os.path.exists(rep_dir):
    os.makedirs(rep_dir)
csv_file_dir = os.path.join(rep_dir, "mediane_niveau_vie.csv")
mdnv_data.to_csv(csv_file_dir, index=False)

# %%
needed_cols = ['Code géographique', 'Taux de pauvreté-Ensemble (%)']

tp_data = data.drop(columns=[col for col in data.columns if col not in needed_cols])
tp_data
# Out:
#       Code géographique Taux de pauvreté-Ensemble (%)
# 0                 01001                             s
# 1                 01002                             s
# 2                 01004                          17,0
# 3                 01005                             s
# 4                 01006                             s
# ...                 ...                           ...
# 34914             97420                          34,0
# 34915             97421                          54,0
# 34916             97422                          38,0
# 34917             97423                          37,0
# 34918             97424                          51,0
#
# [34919 rows x 2 columns]

# %%
import os

rep_dir = "E:\Ingénierie 1 EISI\MSPR 1\Projet MSPR Big Data\Datasets\Extraxted Data"

csv_file_dir = os.path.join(rep_dir, "taux_pauvrete.csv")
tp_data.to_csv(csv_file_dir, index=False)
